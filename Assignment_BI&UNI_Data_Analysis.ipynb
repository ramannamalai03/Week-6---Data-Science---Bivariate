# %%
#1. Replace the NaN values with correct value
import pandas as pd

# %%
dataset=pd.read_csv("Placement_Data_Full_Class.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2      3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4.0      M  56.00  Central  52.00  Central   Science     52.00
# 4      5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 212  211.0      M  80.60   Others  82.00   Others  Commerce     77.60
# 213  212.0      M  58.00   Others  60.00   Others   Science     72.00
# 214  213.0      M  67.00   Others  67.00   Others  Commerce     73.00
# 215  214.0      F  74.00   Others  66.00   Others  Commerce     58.00
# 216  215.0      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#Finding the total NAN values on the dataset columns
dataset.isnull().sum()
# Out:
# sl_no              2
# gender             2
# ssc_p              2
# ssc_b              2
# hsc_p              2
# hsc_b              2
# hsc_s              2
# degree_p           2
# degree_t           2
# workex             2
# etest_p            2
# specialisation     2
# mba_p              2
# status             2
# salary            69
# dtype: int64

# %%
#Splitting the Quan and Qual
quan=['ssc_p','hsc_p','degree_p','etest_p','mba_p','salary']
qual=['sl_no','gender','ssc_b','hsc_b','degree_t','workex','specialisation','status']

# %%
quan
# Out:
# ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
#Replacing the salary columns with '0', so that NAN values will be replaced with '0'
dataset['salary'].fillna(0,inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\1228075952.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['salary'].fillna(0,inplace=True)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2      3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4.0      M  56.00  Central  52.00  Central   Science     52.00
# 4      5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 212  211.0      M  80.60   Others  82.00   Others  Commerce     77.60
# 213  212.0      M  58.00   Others  60.00   Others   Science     72.00
# 214  213.0      M  67.00   Others  67.00   Others  Commerce     73.00
# 215  214.0      F  74.00   Others  66.00   Others  Commerce     58.00
# 216  215.0      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.isna().sum()
# Out:
# sl_no             2
# gender            2
# ssc_p             2
# ssc_b             2
# hsc_p             2
# hsc_b             2
# hsc_s             2
# degree_p          2
# degree_t          2
# workex            2
# etest_p           2
# specialisation    2
# mba_p             2
# status            2
# salary            0
# dtype: int64

# %%
dataset.dropna(inplace=True)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2      3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4.0      M  56.00  Central  52.00  Central   Science     52.00
# 4      5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 212  211.0      M  80.60   Others  82.00   Others  Commerce     77.60
# 213  212.0      M  58.00   Others  60.00   Others   Science     72.00
# 214  213.0      M  67.00   Others  67.00   Others  Commerce     73.00
# 215  214.0      F  74.00   Others  66.00   Others  Commerce     58.00
# 216  215.0      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.isna().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
dataset.count()
# Out:
# sl_no             215
# gender            215
# ssc_p             215
# ssc_b             215
# hsc_p             215
# hsc_b             215
# hsc_s             215
# degree_p          215
# degree_t          215
# workex            215
# etest_p           215
# specialisation    215
# mba_p             215
# status            215
# salary            215
# dtype: int64

# %%
#2. How many of them are not placed?

count=dataset['status'].value_counts()['Not Placed']
count1=dataset['status'].value_counts()['Placed']

# %%
count
# Out:
# 67

# %%
count1
# Out:
# 148

# %%
#3. Find the reason for non-placement from the dataset?
    ----->As per the dataset, the students doesn't have the experience so they are not placed
# Out:
#   Cell In[17], line 2
#     ----->As per the dataset, the students doesn't have the experience so they are not placed
#     ^
# IndentationError: unexpected indent

# %%
import matplotlib.pyplot as plt
workex=['Yes','No']
status=['Placed','Not - Placed']
plt.figure(figsize=(8,4))
plt.bar(workex,status,color='blue')
plt.xlabel('Work Experience')

plt.ylabel('Placement Status')
plt.title('Placement status by Work Experience')
plt.show()

# %%
#4)What kind of relation between salary and mba_p?

# %%
dataset=dataset.drop(columns='sl_no')
dataset=dataset.dropna()

# %%
dataset
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 212      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 213      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 214      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 215      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 216      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
numerical_values=dataset.select_dtypes(include=['int64','float64']).columns
cov_matrix=dataset[numerical_values].cov()

# %%
dataset[numerical_values].cov()
# Out:
#                   ssc_p          hsc_p       degree_p        etest_p  \
# ssc_p        117.228377      60.348373      42.897137      37.659225
# hsc_p         60.348373     118.755706      34.819820      35.461678
# degree_p      42.897137      34.819820      54.151103      21.929469
# etest_p       37.659225      35.461678      21.929469     176.251018
# mba_p         24.535952      22.555846      17.272020      16.886973
# salary    901754.893936  763359.777657  465131.504238  384234.419257
#
#                   mba_p        salary
# ssc_p         24.535952  9.017549e+05
# hsc_p         22.555846  7.633598e+05
# degree_p      17.272020  4.651315e+05
# etest_p       16.886973  3.842344e+05
# mba_p         34.028376  1.262455e+05
# salary    126245.485547  2.395714e+10

# %%
#As per the relation of Salary and MBA_P is 126245.4855 which is a Positive Correlation that is Salary increases then MBA also increases 
which is directly proportional relationship.

# %%
dataset[numerical_values].corr()
# Out:
#              ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# ssc_p     1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p     0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %%
# As per the relation of Salary and MBA_P is 0.139823 which is Positive correlation that means independent variable is dirrectly
proportional to dependent variable.

# %%
#5)Which specialization is getting minimum salary
average_salary=dataset.groupby('specialisation')['salary'].mean()
print(average_salary)
# Out:
# specialisation
# Mkt&Fin    236591.666667
# Mkt&HR     150842.105263
# Name: salary, dtype: float64

# %%
#6.HOW MANY OF THEM GETTING ABOVE 500000 SALARY
max_salary=dataset[dataset['salary']>500000].shape[0]
print("Number of person above 500000 salary:",max_salary)
# Out:
# Number of person above 500000 salary: 3

# %%
#7) Test the Analysis of Variance between etest_p and mba_p at signifance level 5%. (Make decision using Hypothesis Testing)

import scipy.stats as stats
stats.f_oneway(dataset['etest_p'],dataset['mba_p'])
# Out:
# F_onewayResult(statistic=98.64487057324709, pvalue=4.672547689133636e-21)

# %%
#8) Test the similarity between the degree_t(Sci&Tech) and specialisation (Mkt&HR) with respect to salary  at significance level of 5%.(Make decision using Hypothesis Testing)

from scipy.stats import ttest_ind
dataset=dataset.dropna()
sci_Salary=dataset[dataset['degree_t']=='Sci&Tech']['salary']
mkt_Salary=dataset[dataset['specialisation']=='Mkt&HR']['salary']
ttest_ind(sci_Salary,mkt_Salary)
# Out:
# TtestResult(statistic=2.692041243555374, pvalue=0.007897969943471191, df=152.0)

# %%
#9) Convert the normal distribution to standard normal distribution for salary column

def stdNBgraph(dataset):
    #Converted to Standard Normal distribution
    import seaborn as sns
    mean=dataset.mean()
    std=dataset.std()
    values=[i for i in dataset]
    z_score=[((j-mean)/std) for j in values]
    sns.distplot(z_score,kde=True)
    sum(z_score)/len(z_score)
    #z_score.std()

# %%
stdNBgraph(dataset['salary'])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\2272997333.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score,kde=True)

# %%
#10) What is the probability Density Function of the salary range from 700000 to 900000?

import seaborn as sns
sns.distplot(dataset['salary'])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\2678534274.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['salary'])
# <Axes: xlabel='salary', ylabel='Density'>

# %%
def get_pdf_probability(dataset, startrange, endrange):
    
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    # generate a sample
    sample = dataset
    # calculate parameters
    sample_mean =sample.mean()
    sample_std = sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
    # define the distribution
    dist = norm(sample_mean, sample_std)
    
    # sample probabilities for a range of outcomes
    values = [value for value in range(startrange, endrange)]
    probabilities = [dist.pdf(value) for value in values]    
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset["salary"],700000,900000)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18612\301725591.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
# Mean=198702.326, Standard Deviation=154780.927
# The area between range(700000,900000):0.0005973310593974868
# 0.0005973310593974868

# %%
#11. Test the similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p at significance level of 5%.(Make decision using Hypothesis Testing)

from scipy.stats import ttest_rel
dataset=dataset.dropna()
science_d=dataset[dataset['degree_t']=='Sci&Tech']['etest_p']
science_d1=dataset[dataset['degree_t']=='Sci&Tech']['mba_p']
ttest_rel(science_d,science_d1)
# Out:
# TtestResult(statistic=5.0049844583693615, pvalue=5.5179206005054e-06, df=58)

# %%
pip install statsmodel
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement statsmodel (from versions: none)
# ERROR: No matching distribution found for statsmodel

# %%
#12. Which parameter is highly correlated with salary?
from statsmodels.stats.outliers_influence import variance_inflation_factor
def calc_vif(X):
    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    return(vif)

# %%
calc_vif(dataset['ssc_p','hsc_p','degree_p','etest_p','mba_p','salary'])

# %%
#13) Plot any useful graph and explain it

import matplotlib.pyplot as plt
placement_status = ['Placed', 'Not Placed']
plt.figure(figsize=(9, 5))
plt.bar(placement_status, count, color=['green', 'red'])
plt.xlabel('status')
plt.ylabel('Count')
plt.title('Placement Status Bar Chart')
plt.show()
